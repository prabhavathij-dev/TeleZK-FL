# %% [markdown]
# # TeleZK-FL Kaggle Environment Setup
# Run this block first to prepare the environment, dataset, and code repository.

# %%
# !pip install wfdb pyyaml psutil

# %%
# !git clone https://github.com/prabhavathij-dev/TeleZK-FL.git
# %cd TeleZK-FL

# %%
# Link Kaggle CheXpert inner dataset folder to our expected path
# !mkdir -p data/chexpert
# !ln -s /kaggle/input/chexpert/CheXpert-v1.0-small data/chexpert/CheXpert-v1.0-small
# !ls -la data/chexpert/

# %%
# Download PTB-XL directly from PhysioNet
# !python -c "import wfdb; wfdb.dl_database('ptb-xl/1.0.3', 'data/ptbxl')"

# %%
# Verify GPU is available and accessible
import torch
print(f"GPU available: {torch.cuda.is_available()}")
print(f"GPU name: {torch.cuda.get_device_name(0)}")

# %%
# Run Data Loading Smoke Tests to verify links
# !python tests/test_data_loading.py

# %% [markdown]
# # Initial Experiments (Seed 42) & Sanity Checks
# This section runs the centralized sanity check followed by baseline and TeleZK-FL experiments on **IID** partitions with a single random seed (42).

# %%
# Centralized Sanity Check (Upper Bound)
# !python tests/test_centralized_training.py
# !zip -r ../results_centralized.zip results/

# %%
# 1. FL Standard Baselines (IID)
# !python main.py --config config/chexpert_iid.yaml --seed 42 --mode baseline
# !zip -r ../results_seed42.zip results/

# !python main.py --config config/ptbxl_iid.yaml --seed 42 --mode baseline
# !zip -r ../results_seed42.zip results/

# %%
# 2. FL + DP Baselines (IID)
# !python main.py --config config/chexpert_iid.yaml --seed 42 --mode dp
# !zip -r ../results_seed42.zip results/

# !python main.py --config config/ptbxl_iid.yaml --seed 42 --mode dp
# !zip -r ../results_seed42.zip results/

# %%
# 3. TeleZK-FL Experiments (IID)
# !python main.py --config config/chexpert_iid.yaml --seed 42 --mode telezk
# !zip -r ../results_seed42.zip results/

# !python main.py --config config/ptbxl_iid.yaml --seed 42 --mode telezk
# !zip -r ../results_seed42.zip results/

# %%
# 4. Standalone Microbenchmarks
# !python main.py --benchmark-only
# !zip -r ../results_seed42.zip results/
